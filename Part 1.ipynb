# %%
import numpy as np
import pandas as pd
from scipy import signal
import json
from datetime import datetime
from collections import deque
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

class MouseDataProcessor:
    def __init__(self, window_size=100, sampling_rate=50):
        self.window_size = window_size
        self.sampling_rate = sampling_rate  # Hz
        self.scaler = StandardScaler()
        
    def load_mouse_data(self, file_path='/mouse_data.json'):
        """Load mouse data from JSON file"""
        data = []
        with open(file_path, 'r') as f:
            for line in f:
                try:
                    entry = json.loads(line.strip())
                    if entry.get('Event') == 'Move':
                        data.append({
                            'x': entry['Position']['X'],
                            'y': entry['Position']['Y'],
                            'timestamp': entry['Time']
                        })
                except:
                    continue
        return pd.DataFrame(data)
    
    def calculate_velocity_acceleration(self, df):
        """Calculate velocity and acceleration features"""
        # Calculate time differences
        df['dt'] = df['timestamp'].diff().fillna(0)
        
        # Calculate distances
        df['dx'] = df['x'].diff().fillna(0)
        df['dy'] = df['y'].diff().fillna(0)
        df['distance'] = np.sqrt(df['dx']**2 + df['dy']**2)
        
        # Calculate velocities (rate of change)
        df['vx'] = df['dx'] / (df['dt'] + 1e-8)
        df['vy'] = df['dy'] / (df['dt'] + 1e-8)
        df['speed'] = np.sqrt(df['vx']**2 + df['vy']**2)
        
        # Calculate accelerations (rate of change of rate of change)
        df['ax'] = df['vx'].diff() / (df['dt'] + 1e-8)
        df['ay'] = df['vy'].diff() / (df['dt'] + 1e-8)
        df['acceleration'] = np.sqrt(df['ax']**2 + df['ay']**2)
        
        # Calculate jerk (rate of change of acceleration)
        df['jerk'] = df['acceleration'].diff() / (df['dt'] + 1e-8)
        
        # Calculate directional changes
        df['direction'] = np.arctan2(df['dy'], df['dx'])
        df['direction_change'] = np.abs(df['direction'].diff()).fillna(0)
        
        # Calculate curvature
        df['curvature'] = df['direction_change'] / (df['distance'] + 1e-8)
        
        return df
    
    def extract_statistical_features(self, df):
        """Extract statistical features for anomaly detection"""
        features = []
        
        # Speed statistics
        features.extend([
            df['speed'].mean(),
            df['speed'].std(),
            df['speed'].max(),
            df['speed'].min(),
            np.percentile(df['speed'], 75) - np.percentile(df['speed'], 25)
        ])
        
        # Acceleration statistics
        features.extend([
            df['acceleration'].mean(),
            df['acceleration'].std(),
            df['acceleration'].max(),
            df['acceleration'].skew() if len(df) > 1 else 0
        ])
        
        # Movement pattern features
        features.extend([
            df['direction_change'].mean(),
            df['curvature'].mean(),
            df['jerk'].mean(),
            df['jerk'].std(),
            len(df[df['speed'] > df['speed'].mean()]) / len(df)  # Percentage of fast movements
        ])
        
        # Temporal features
        features.extend([
            df['dt'].mean(),
            df['dt'].std(),
            1.0 / (df['dt'].mean() + 1e-8)  # Sampling frequency
        ])
        
        return np.array(features)
    
    def create_sequences(self, df, sequence_length=50):
        """Create sequences for LSTM training"""
        processed_df = self.calculate_velocity_acceleration(df)
        
        # Select key features for sequence modeling
        feature_columns = ['speed', 'acceleration', 'direction_change', 
                          'curvature', 'jerk', 'dt']
        
        # Fill NaN values
        for col in feature_columns:
            processed_df[col] = processed_df[col].fillna(0)
        
        # Create sequences
        sequences = []
        for i in range(len(processed_df) - sequence_length + 1):
            seq = processed_df[feature_columns].iloc[i:i+sequence_length].values
            sequences.append(seq)
        
        return np.array(sequences)
    
    def preprocess_for_training(self, sequences):
        """Preprocess sequences for model training"""
        # Reshape for scaling
        original_shape = sequences.shape
        sequences_reshaped = sequences.reshape(-1, sequences.shape[-1])
        
        # Scale features
        sequences_scaled = self.scaler.fit_transform(sequences_reshaped)
        
        # Reshape back
        sequences_scaled = sequences_scaled.reshape(original_shape)
        
        return sequences_scaled

# %%
class MouseAnomalyDetector:
    def __init__(self, sequence_length=50, n_features=6):
        self.sequence_length = sequence_length
        self.n_features = n_features
        self.model = None
        self.threshold = None
        
    def build_model(self):
        """Build LSTM autoencoder for anomaly detection"""
        model = Sequential([
            # Encoder
            LSTM(64, return_sequences=True, input_shape=(self.sequence_length, self.n_features)),
            Dropout(0.2),
            LSTM(32, return_sequences=True),
            Dropout(0.2),
            LSTM(16, return_sequences=False),
            
            # Decoder
            Dense(16, activation='relu'),
            Dense(32, activation='relu'),
            Dense(self.sequence_length * self.n_features, activation='linear')
        ])
        
        model.compile(
            optimizer='adam',
            loss=tf.keras.losses.MeanSquaredError(),
            metrics=[tf.keras.metrics.MeanAbsoluteError()]
        )
        
        self.model = model
        return model
    
    def train(self, X_train, epochs=100, batch_size=32, validation_split=0.2):
        """Train the anomaly detection model"""
        if self.model is None:
            self.build_model()
        
        # Prepare target (for autoencoder, input = output)
        y_train = X_train.reshape(X_train.shape[0], -1)
        
        # Train model
        history = self.model.fit(
            X_train, y_train,
            epochs=epochs,
            batch_size=batch_size,
            validation_split=validation_split,
            verbose=1,
            shuffle=True
        )
        
        # Calculate reconstruction threshold
        predictions = self.model.predict(X_train)
        mse = np.mean((predictions - y_train) ** 2, axis=1)
        self.threshold = np.percentile(mse, 95)  # 95th percentile
        
        return history
    
    def predict_anomaly(self, X_test):
        """Predict anomalies in test data"""
        if self.model is None:
            raise ValueError("Model not trained yet!")
        
        # Get predictions
        predictions = self.model.predict(X_test)
        y_test = X_test.reshape(X_test.shape[0], -1)
        
        # Calculate reconstruction error
        mse = np.mean((predictions - y_test) ** 2, axis=1)
        
        # Detect anomalies
        anomalies = mse > self.threshold
        anomaly_scores = mse / self.threshold
        
        return anomalies, anomaly_scores
    
    def save_model(self, filepath):
        """Save trained model"""
        self.model.save(filepath)
        
        # Save threshold and other parameters
        import pickle
        with open(filepath.replace('.h5', '_params.pkl'), 'wb') as f:
            pickle.dump({
                'threshold': self.threshold,
                'sequence_length': self.sequence_length,
                'n_features': self.n_features
            }, f)
    
    def load_model(self, filepath):
        """Load trained model"""
        self.model = tf.keras.models.load_model(filepath)
        
        # Load threshold and parameters
        import pickle
        with open(filepath.replace('.h5', '_params.pkl'), 'rb') as f:
            params = pickle.load(f)
            self.threshold = params['threshold']
            self.sequence_length = params['sequence_length']
            self.n_features = params['n_features']

# %%
def train_mouse_anomaly_detector(data_file_path, model_save_path):
    """Complete training pipeline"""
    
    # Initialize processor
    processor = MouseDataProcessor(window_size=100, sampling_rate=50)
    
    # Load and process data
    print("Loading mouse data...")
    df = processor.load_mouse_data(data_file_path)
    print(f"Loaded {len(df)} mouse movement records")
    
    # Create sequences
    print("Creating sequences...")
    sequences = processor.create_sequences(df, sequence_length=50)
    print(f"Created {len(sequences)} sequences")
    
    # Preprocess for training
    print("Preprocessing sequences...")
    sequences_scaled = processor.preprocess_for_training(sequences)
    
    # Initialize and train model
    print("Training model...")
    detector = MouseAnomalyDetector(sequence_length=50, n_features=6)
    history = detector.train(sequences_scaled, epochs=100, batch_size=32)
    
    # Save model
    print("Saving model...")
    detector.save_model(model_save_path)
    
    # Save scaler
    import pickle
    with open(model_save_path.replace('.h5', '_scaler.pkl'), 'wb') as f:
        pickle.dump(processor.scaler, f)
    
    print("Training completed!")
    return detector, processor, history

# Usage
if __name__ == "__main__":
    # Train the model
    detector, processor, history = train_mouse_anomaly_detector(
        'mouse_data.json', 
        'mouse_anomaly_model.h5'
    )
# Out:
# Loading mouse data...
# Loaded 15465 mouse movement records
# Creating sequences...
# Created 15416 sequences
# Preprocessing sequences...
# Training model...
# Epoch 1/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 1.0980 - mean_absolute_error: 0.3975 - val_loss: 0.4319 - val_mean_absolute_error: 0.3030
# Epoch 2/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 1.0082 - mean_absolute_error: 0.3949 - val_loss: 0.4224 - val_mean_absolute_error: 0.2801
# Epoch 3/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 1.0071 - mean_absolute_error: 0.3869 - val_loss: 0.4204 - val_mean_absolute_error: 0.2737
# Epoch 4/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 0.9827 - mean_absolute_error: 0.3816 - val_loss: 0.4172 - val_mean_absolute_error: 0.2803
# Epoch 5/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 1.0416 - mean_absolute_error: 0.3858 - val_loss: 0.4156 - val_mean_absolute_error: 0.2789
# Epoch 6/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 1.0373 - mean_absolute_error: 0.3835 - val_loss: 0.4127 - val_mean_absolute_error: 0.2755
# Epoch 7/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 0.9917 - mean_absolute_error: 0.3809 - val_loss: 0.4110 - val_mean_absolute_error: 0.2727
# Epoch 8/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9933 - mean_absolute_error: 0.3801 - val_loss: 0.4100 - val_mean_absolute_error: 0.2724
# Epoch 9/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 1.0127 - mean_absolute_error: 0.3833 - val_loss: 0.4089 - val_mean_absolute_error: 0.2754
# Epoch 10/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 1.0178 - mean_absolute_error: 0.3847 - val_loss: 0.4074 - val_mean_absolute_error: 0.2736
# Epoch 11/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9969 - mean_absolute_error: 0.3846 - val_loss: 0.4038 - val_mean_absolute_error: 0.2720
# Epoch 12/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9884 - mean_absolute_error: 0.3842 - val_loss: 0.4024 - val_mean_absolute_error: 0.2666
# Epoch 13/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 1.0028 - mean_absolute_error: 0.3829 - val_loss: 0.4015 - val_mean_absolute_error: 0.2719
# Epoch 14/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.9838 - mean_absolute_error: 0.3845 - val_loss: 0.4007 - val_mean_absolute_error: 0.2698
# Epoch 15/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9779 - mean_absolute_error: 0.3846 - val_loss: 0.3999 - val_mean_absolute_error: 0.2718
# Epoch 16/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9749 - mean_absolute_error: 0.3856 - val_loss: 0.3979 - val_mean_absolute_error: 0.2719
# Epoch 17/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9966 - mean_absolute_error: 0.3871 - val_loss: 0.3965 - val_mean_absolute_error: 0.2688
# Epoch 18/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9933 - mean_absolute_error: 0.3872 - val_loss: 0.3947 - val_mean_absolute_error: 0.2681
# Epoch 19/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9481 - mean_absolute_error: 0.3804 - val_loss: 0.3948 - val_mean_absolute_error: 0.2726
# Epoch 20/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9633 - mean_absolute_error: 0.3819 - val_loss: 0.3938 - val_mean_absolute_error: 0.2606
# Epoch 21/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9635 - mean_absolute_error: 0.3828 - val_loss: 0.3942 - val_mean_absolute_error: 0.2664
# Epoch 22/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.9585 - mean_absolute_error: 0.3827 - val_loss: 0.3952 - val_mean_absolute_error: 0.2788
# Epoch 23/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9420 - mean_absolute_error: 0.3811 - val_loss: 0.3913 - val_mean_absolute_error: 0.2668
# Epoch 24/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9549 - mean_absolute_error: 0.3791 - val_loss: 0.3908 - val_mean_absolute_error: 0.2566
# Epoch 25/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9545 - mean_absolute_error: 0.3788 - val_loss: 0.3906 - val_mean_absolute_error: 0.2683
# Epoch 26/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9587 - mean_absolute_error: 0.3793 - val_loss: 0.3891 - val_mean_absolute_error: 0.2607
# Epoch 27/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9706 - mean_absolute_error: 0.3782 - val_loss: 0.3882 - val_mean_absolute_error: 0.2627
# Epoch 28/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9469 - mean_absolute_error: 0.3758 - val_loss: 0.3895 - val_mean_absolute_error: 0.2632
# Epoch 29/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9184 - mean_absolute_error: 0.3752 - val_loss: 0.3877 - val_mean_absolute_error: 0.2645
# Epoch 30/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.9726 - mean_absolute_error: 0.3784 - val_loss: 0.3880 - val_mean_absolute_error: 0.2653
# Epoch 31/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9720 - mean_absolute_error: 0.3802 - val_loss: 0.3872 - val_mean_absolute_error: 0.2637
# Epoch 32/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9369 - mean_absolute_error: 0.3762 - val_loss: 0.3872 - val_mean_absolute_error: 0.2676
# Epoch 33/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9408 - mean_absolute_error: 0.3779 - val_loss: 0.3872 - val_mean_absolute_error: 0.2645
# Epoch 34/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9377 - mean_absolute_error: 0.3767 - val_loss: 0.3862 - val_mean_absolute_error: 0.2631
# Epoch 35/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9613 - mean_absolute_error: 0.3793 - val_loss: 0.3858 - val_mean_absolute_error: 0.2660
# Epoch 36/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9269 - mean_absolute_error: 0.3786 - val_loss: 0.3852 - val_mean_absolute_error: 0.2652
# Epoch 37/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9595 - mean_absolute_error: 0.3803 - val_loss: 0.3845 - val_mean_absolute_error: 0.2660
# Epoch 38/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.9204 - mean_absolute_error: 0.3751 - val_loss: 0.3836 - val_mean_absolute_error: 0.2661
# Epoch 39/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9169 - mean_absolute_error: 0.3747 - val_loss: 0.3815 - val_mean_absolute_error: 0.2670
# Epoch 40/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.8878 - mean_absolute_error: 0.3697 - val_loss: 0.3805 - val_mean_absolute_error: 0.2650
# Epoch 41/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9431 - mean_absolute_error: 0.3747 - val_loss: 0.3841 - val_mean_absolute_error: 0.2766
# Epoch 42/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9371 - mean_absolute_error: 0.3748 - val_loss: 0.3801 - val_mean_absolute_error: 0.2618
# Epoch 43/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9089 - mean_absolute_error: 0.3740 - val_loss: 0.3810 - val_mean_absolute_error: 0.2677
# Epoch 44/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9090 - mean_absolute_error: 0.3722 - val_loss: 0.3787 - val_mean_absolute_error: 0.2633
# Epoch 45/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9170 - mean_absolute_error: 0.3709 - val_loss: 0.3790 - val_mean_absolute_error: 0.2643
# Epoch 46/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.9126 - mean_absolute_error: 0.3710 - val_loss: 0.3782 - val_mean_absolute_error: 0.2628
# Epoch 47/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9109 - mean_absolute_error: 0.3717 - val_loss: 0.3779 - val_mean_absolute_error: 0.2581
# Epoch 48/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9246 - mean_absolute_error: 0.3723 - val_loss: 0.3776 - val_mean_absolute_error: 0.2633
# Epoch 49/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9451 - mean_absolute_error: 0.3727 - val_loss: 0.3777 - val_mean_absolute_error: 0.2658
# Epoch 50/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9625 - mean_absolute_error: 0.3747 - val_loss: 0.3790 - val_mean_absolute_error: 0.2628
# Epoch 51/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.8934 - mean_absolute_error: 0.3734 - val_loss: 0.3812 - val_mean_absolute_error: 0.2664
# Epoch 52/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9098 - mean_absolute_error: 0.3765 - val_loss: 0.3754 - val_mean_absolute_error: 0.2587
# Epoch 53/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9170 - mean_absolute_error: 0.3720 - val_loss: 0.3751 - val_mean_absolute_error: 0.2659
# Epoch 54/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.9149 - mean_absolute_error: 0.3743 - val_loss: 0.3742 - val_mean_absolute_error: 0.2655
# Epoch 55/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9029 - mean_absolute_error: 0.3733 - val_loss: 0.3738 - val_mean_absolute_error: 0.2630
# Epoch 56/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9024 - mean_absolute_error: 0.3723 - val_loss: 0.3732 - val_mean_absolute_error: 0.2610
# Epoch 57/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9299 - mean_absolute_error: 0.3731 - val_loss: 0.3725 - val_mean_absolute_error: 0.2609
# Epoch 58/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.8785 - mean_absolute_error: 0.3689 - val_loss: 0.3721 - val_mean_absolute_error: 0.2625
# Epoch 59/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9099 - mean_absolute_error: 0.3705 - val_loss: 0.3730 - val_mean_absolute_error: 0.2673
# Epoch 60/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.8944 - mean_absolute_error: 0.3701 - val_loss: 0.3729 - val_mean_absolute_error: 0.2685
# Epoch 61/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.9265 - mean_absolute_error: 0.3746 - val_loss: 0.3719 - val_mean_absolute_error: 0.2574
# Epoch 62/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.8907 - mean_absolute_error: 0.3703 - val_loss: 0.3728 - val_mean_absolute_error: 0.2622
# Epoch 63/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9118 - mean_absolute_error: 0.3720 - val_loss: 0.3713 - val_mean_absolute_error: 0.2640
# Epoch 64/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.9022 - mean_absolute_error: 0.3704 - val_loss: 0.3704 - val_mean_absolute_error: 0.2615
# Epoch 65/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.8796 - mean_absolute_error: 0.3688 - val_loss: 0.3712 - val_mean_absolute_error: 0.2643
# Epoch 66/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9131 - mean_absolute_error: 0.3749 - val_loss: 0.3702 - val_mean_absolute_error: 0.2667
# Epoch 67/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.9266 - mean_absolute_error: 0.3733 - val_loss: 0.3703 - val_mean_absolute_error: 0.2630
# Epoch 68/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9133 - mean_absolute_error: 0.3740 - val_loss: 0.3700 - val_mean_absolute_error: 0.2624
# Epoch 69/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.8998 - mean_absolute_error: 0.3713 - val_loss: 0.3691 - val_mean_absolute_error: 0.2607
# Epoch 70/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.8835 - mean_absolute_error: 0.3728 - val_loss: 0.3742 - val_mean_absolute_error: 0.2705
# Epoch 71/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.9184 - mean_absolute_error: 0.3763 - val_loss: 0.3725 - val_mean_absolute_error: 0.2759
# Epoch 72/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.8974 - mean_absolute_error: 0.3712 - val_loss: 0.3690 - val_mean_absolute_error: 0.2637
# Epoch 73/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.8904 - mean_absolute_error: 0.3719 - val_loss: 0.3682 - val_mean_absolute_error: 0.2647
# Epoch 74/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.9064 - mean_absolute_error: 0.3737 - val_loss: 0.3683 - val_mean_absolute_error: 0.2637
# Epoch 75/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.9091 - mean_absolute_error: 0.3722 - val_loss: 0.3676 - val_mean_absolute_error: 0.2648
# Epoch 76/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.9060 - mean_absolute_error: 0.3735 - val_loss: 0.3720 - val_mean_absolute_error: 0.2558
# Epoch 77/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.9216 - mean_absolute_error: 0.3745 - val_loss: 0.3684 - val_mean_absolute_error: 0.2687
# Epoch 78/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.8931 - mean_absolute_error: 0.3729 - val_loss: 0.3667 - val_mean_absolute_error: 0.2618
# Epoch 79/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.8896 - mean_absolute_error: 0.3699 - val_loss: 0.3668 - val_mean_absolute_error: 0.2621
# Epoch 80/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.8663 - mean_absolute_error: 0.3688 - val_loss: 0.3664 - val_mean_absolute_error: 0.2631
# Epoch 81/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.9129 - mean_absolute_error: 0.3724 - val_loss: 0.3661 - val_mean_absolute_error: 0.2611
# Epoch 82/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.8797 - mean_absolute_error: 0.3695 - val_loss: 0.3659 - val_mean_absolute_error: 0.2598
# Epoch 83/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.8864 - mean_absolute_error: 0.3713 - val_loss: 0.3655 - val_mean_absolute_error: 0.2623
# Epoch 84/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.8976 - mean_absolute_error: 0.3722 - val_loss: 0.3660 - val_mean_absolute_error: 0.2593
# Epoch 85/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.8860 - mean_absolute_error: 0.3741 - val_loss: 0.3658 - val_mean_absolute_error: 0.2635
# Epoch 86/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.8819 - mean_absolute_error: 0.3694 - val_loss: 0.3648 - val_mean_absolute_error: 0.2618
# Epoch 87/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.8811 - mean_absolute_error: 0.3669 - val_loss: 0.3658 - val_mean_absolute_error: 0.2674
# Epoch 88/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.8875 - mean_absolute_error: 0.3698 - val_loss: 0.3649 - val_mean_absolute_error: 0.2636
# Epoch 89/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.8860 - mean_absolute_error: 0.3708 - val_loss: 0.3639 - val_mean_absolute_error: 0.2621
# Epoch 90/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.8724 - mean_absolute_error: 0.3680 - val_loss: 0.3642 - val_mean_absolute_error: 0.2619
# Epoch 91/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.8894 - mean_absolute_error: 0.3694 - val_loss: 0.3631 - val_mean_absolute_error: 0.2650
# Epoch 92/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.8716 - mean_absolute_error: 0.3689 - val_loss: 0.3624 - val_mean_absolute_error: 0.2607
# Epoch 93/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.8938 - mean_absolute_error: 0.3708 - val_loss: 0.3627 - val_mean_absolute_error: 0.2629
# Epoch 94/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.8827 - mean_absolute_error: 0.3707 - val_loss: 0.3615 - val_mean_absolute_error: 0.2582
# Epoch 95/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9241 - mean_absolute_error: 0.3725 - val_loss: 0.3635 - val_mean_absolute_error: 0.2672
# Epoch 96/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.9041 - mean_absolute_error: 0.3721 - val_loss: 0.3631 - val_mean_absolute_error: 0.2640
# Epoch 97/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.8989 - mean_absolute_error: 0.3691 - val_loss: 0.3625 - val_mean_absolute_error: 0.2607
# Epoch 98/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.8895 - mean_absolute_error: 0.3671 - val_loss: 0.3616 - val_mean_absolute_error: 0.2597
# Epoch 99/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.8650 - mean_absolute_error: 0.3664 - val_loss: 0.3614 - val_mean_absolute_error: 0.2606
# Epoch 100/100
# 386/386 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.8752 - mean_absolute_error: 0.3670 - val_loss: 0.3603 - val_mean_absolute_error: 0.2584
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saving model...
# Training completed!

# %%
MouseDataProcessor.df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 MouseDataProcessor.df.head()
#
# AttributeError: type object 'MouseDataProcessor' has no attribute 'df'
